# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Read Data Function
def read_data(filename):
    
    # Retrieve Data
    data = pd.read_csv(filename)
    
    # Drop Columns
    clean = data.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Date'])
    
    # Drop Last Row
    clean = clean[:-1].copy()
    
    # Drop missing data
    clean = clean.dropna()
    
    # Rename Columns
    cols = ['Year', 'Population', 'CH4', 'CO2', 'GHG', 'HFC', 'N2O', 'PFC', 'SF6']
    clean.columns = cols
    
    return clean

# %%
# Run Model (Machine Learning)
def run_model(clean):
        
    # Set Training and Testing Split
    training = clean.loc[clean['Year']<2010]
    testing = clean.loc[clean['Year']>=2010]

    # Set Variables
    X_train = training[['Year']]
    y_train = training['Population']
    X_test = testing[['Year']]
    y_test = testing['Population']
    X = clean[['Year']]
    y = clean['Population']

    # Linear Regression Model
    from sklearn.linear_model import LinearRegression
    
    model = LinearRegression()

    # Train Modele
    model.fit(X_train, y_train)

    # Score for 1991-2009
    print(f"Train Score: {model.score(X_train, y_train)}")

    # Score for 2010+
    print(f"Test Score: {model.score(X_test, y_test)}")

    # Predictions vs Actual
    predictions = model.predict(X)
    print(f"Actual: {y[0]}")
    print(f"Predicted: {predictions[0]}")
    print(f"Error: {predictions[0]-y[0]}")

    return pd.DataFrame({"Year": clean["Year"],
                         "Predicted": predictions,
                         "Actual": y,
                         "Error": predictions - y,
                         "Country": country})

# %%
final = pd.DataFrame(columns = ["Year", "Predicted", "Actual", "Error", "Country"])

for filename in os.listdir("Cleaning/Combined"):
    if ".csv" in filename:
        
        print()
        
        country = filename.replace('.csv', '')
        
        print(country)
        
        clean = read_data("Cleaning/Combined/" + filename)
        
        try:
            output = run_model(clean)
            final = final.append(output)
        
        except:
            print("Error")
# Out:
# Australia
# Train Score: 0.9937126041265244
# Test Score: -0.11620695837059736
# Actual: 17065100
# Predicted: 16934248.571428537
# Error: -130851.42857146263
#
# Canada
# Train Score: 0.9991074391985868
# Test Score: 0.7750585161118898
# Actual: 27691138
# Predicted: 27722816.6789279
# Error: 31678.678927898407
#
# Japan
# Train Score: 0.9436732537488511
# Test Score: -37.95719036742728
# Actual: 123537000
# Predicted: 124043428.5714286
# Error: 506428.571428597
#
# New Zealand
# Train Score: 0.9877339502783713
# Test Score: 0.8747776536970642
# Actual: 3329800
# Predicted: 3419391.428571433
# Error: 89591.42857143283
#
# Russia
# Train Score: 0.906951143094175
# Test Score: -28.41760741557519
# Actual: 147969407
# Predicted: 149607089.28571427
# Error: 1637682.2857142687
#
# Spain
# Train Score: 0.8951378514700741
# Test Score: -82.56231212280693
# Actual: 38867322
# Predicted: 37796456.600000024
# Error: -1070865.3999999762
#
# Switzerland
# Train Score: 0.9797743685773962
# Test Score: -0.9047477832808499
# Actual: 6715519
# Predicted: 6757440.971428558
# Error: 41921.97142855823
#
# Turkey
# Train Score: 0.9997310641095456
# Test Score: 0.8081633099456963
# Actual: 53921760
# Predicted: 53923222.75714278
# Error: 1462.7571427822113
#
# United States
# Train Score: 0.998020890634906
# Test Score: 0.2567427932146229
# Actual: 249623000
# Predicted: 251089303.88571358
# Error: 1466303.8857135773

# %%
# Export 
final.to_csv('Resources/ML_Pop.csv')
