# %%
# Dependencies
import pandas as pd

# %%
# Read CSV
csv = pd.read_csv('Population.csv')
csv
# Out:
#                                          Series Name  Series Code  \
# 0                                  Population, total  SP.POP.TOTL
# 1                                  Population, total  SP.POP.TOTL
# 2                                  Population, total  SP.POP.TOTL
# 3                                  Population, total  SP.POP.TOTL
# 4                                  Population, total  SP.POP.TOTL
# 5                                  Population, total  SP.POP.TOTL
# 6                                  Population, total  SP.POP.TOTL
# 7                                  Population, total  SP.POP.TOTL
# 8                                  Population, total  SP.POP.TOTL
# 9                                  Population, total  SP.POP.TOTL
# 10                                               NaN          NaN
# 11                                               NaN          NaN
# 12                                               NaN          NaN
# ...

# %%
# Drop Columns
cols = csv.drop(columns=['Series Name', 'Series Code', 'Country Code'])
cols
# Out:
#           Country Name  1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  \
# 0            Australia     17065100.0     17284000.0     17495000.0
# 1               Canada     27691138.0     28037420.0     28371264.0
# 2                Japan    123537000.0    123921000.0    124229000.0
# 3   Russian Federation    147969407.0    148394216.0    148538197.0
# 4                Spain     38867322.0     38966376.0     39157685.0
# 5               Turkey     53921760.0     54840590.0     55748948.0
# 6        United States    249623000.0    252981000.0    256514000.0
# 7       United Kingdom     57247586.0     57424897.0     57580402.0
# 8          Switzerland      6715519.0      6799978.0      6875364.0
# 9          New Zealand      3329800.0      3495100.0      3531700.0
# 10                 NaN            NaN            NaN            NaN
# 11                 NaN            NaN            NaN            NaN
# 12                 NaN            NaN            NaN            NaN
# ...

# %%
# Drop Rows
rows = cols.drop([10, 11, 12, 13, 14])
rows
# Out:
#          Country Name  1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  \
# 0           Australia     17065100.0     17284000.0     17495000.0
# 1              Canada     27691138.0     28037420.0     28371264.0
# 2               Japan    123537000.0    123921000.0    124229000.0
# 3  Russian Federation    147969407.0    148394216.0    148538197.0
# 4               Spain     38867322.0     38966376.0     39157685.0
# 5              Turkey     53921760.0     54840590.0     55748948.0
# 6       United States    249623000.0    252981000.0    256514000.0
# 7      United Kingdom     57247586.0     57424897.0     57580402.0
# 8         Switzerland      6715519.0      6799978.0      6875364.0
# 9         New Zealand      3329800.0      3495100.0      3531700.0
#
#    1993 [YR1993]  1994 [YR1994]  1995 [YR1995]  1996 [YR1996]  1997 [YR1997]  \
# 0     17667000.0     17855000.0     18072000.0     18311000.0     18517000.0
# ...

# %%
# Rename Columns
cols_name = ['Country', 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
             2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %%
# Make Duplicate DF, Replace Column Names
pop = rows.copy()
pop.columns = cols_name
pop
# Out:
#               Country         1990         1991         1992         1993  \
# 0           Australia   17065100.0   17284000.0   17495000.0   17667000.0
# 1              Canada   27691138.0   28037420.0   28371264.0   28684764.0
# 2               Japan  123537000.0  123921000.0  124229000.0  124536000.0
# 3  Russian Federation  147969407.0  148394216.0  148538197.0  148458777.0
# 4               Spain   38867322.0   38966376.0   39157685.0   39361262.0
# 5              Turkey   53921760.0   54840590.0   55748948.0   56653804.0
# 6       United States  249623000.0  252981000.0  256514000.0  259919000.0
# 7      United Kingdom   57247586.0   57424897.0   57580402.0   57718614.0
# 8         Switzerland    6715519.0    6799978.0    6875364.0    6938265.0
# 9         New Zealand    3329800.0    3495100.0    3531700.0    3572200.0
#
#           1994         1995         1996         1997         1998  ...  \
# 0   17855000.0   18072000.0   18311000.0   18517000.0   18711000.0  ...
# ...

# %%
# Save DF as CSV
pop.to_csv('Population - Cleaned.csv')
